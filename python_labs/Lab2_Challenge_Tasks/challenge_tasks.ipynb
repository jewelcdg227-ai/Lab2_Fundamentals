# %%
target_name = "DE GUZMAN". upper()
SEED_NUM = 5
redacted_name = ""

execution_log = []

for char in target_name:
    if char in "AEIOU":
        redacted_name += str(SEED_NUM)
        execution_log.append(f"{char} -> {SEED_NUM}")
    else:
        redacted_name += char
        execution_log.append(f"{char} -> {char}")

print("Original Surname:", target_name)
print("SEED_NUM Used:", SEED_NUM)
print("Execution Log:", execution_log)
print("Redacted Output:", redacted_name)
# Out:
# Original Surname: DE GUZMAN
# SEED_NUM Used: 5
# Execution Log: ['D -> D', 'E -> 5', '  ->  ', 'G -> G', 'U -> 5', 'Z -> Z', 'M -> M', 'A -> 5', 'N -> N']
# Redacted Output: D5 G5ZM5N

# %%
engineer_name = "Jewel"

first_letter = engineer_name[0]
ascii_value = ord(first_letter)

loops = len(target_name)

verification_hash = (ascii_value * SEED_NUM) - loops

print("First Letter ASCII (A):", ascii_value)
print("SEED_NUM (B):", SEED_NUM)
print("Total Loops (C):", loops)
print("Verification Hash:", verification_hash)
# Out:
# First Letter ASCII (A): 74
# SEED_NUM (B): 5
# Total Loops (C): 9
# Verification Hash: 361

# %%
correct_password = "jewelcdg227"
attemps = 0

while True:
    password = input("Enter password: ")
    attemps += 1

    if password == correct_password:
        print("Access Granted")
        break
    else:
        print("Access Denied")
print("Attemps before success:", attemps)
# Out:
# Access Denied
# Access Denied
# Access Denied
# Access Granted
# Attemps before success: 4
